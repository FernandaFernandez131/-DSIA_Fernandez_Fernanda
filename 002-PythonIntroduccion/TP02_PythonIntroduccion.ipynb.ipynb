# %% [markdown]
# ## TP02 – Introducción a Python

# %% [markdown]
# Fernández Fernanda

# %% [markdown]
# Variables y operaciones

# %%
nombre = "fernanda"
edad = 29
ciudad = "Buenos Aires"
print(f"Hola, mi nombre es {nombre}, tengo {edad} años y vivo en {ciudad}.")
# Out:
# Hola, mi nombre es fernanda, tengo 29 años y vivo en Buenos Aires.

# %%
numero_uno = 50
numero_dos = 60
suma = numero_uno + numero_dos
resta = numero_uno - numero_dos
multiplicacion = numero_uno * numero_dos
division = numero_uno / numero_dos
print(f"La suma de {numero_uno} y {numero_dos} es {suma}.")
print(f"La resta de {numero_uno} y {numero_dos} es {resta}.")
print(f"La multiplicación de {numero_uno} y {numero_dos} es {multiplicacion}.")
print(f"La división de {numero_uno} y {numero_dos} es {division}.")
# Out:
# La suma de 50 y 60 es 110.
# La resta de 50 y 60 es -10.
# La multiplicación de 50 y 60 es 3000.
# La división de 50 y 60 es 0.8333333333333334.

# %% [markdown]
# Condicionales

# %%
edad = int(input("Ingrese su edad: "))
if edad >= 18:
    print("Usted es mayor de edad")
else:
    print("Usted es menor de edad")
# Out:
# Usted es mayor de edad

# %% [markdown]
# Listas y bucles

# %%
numeros = [1, 2, 3, 4, 5]
suma = 0	
for numero in numeros:
    print(numero)
    suma += numero
print("La suma de los números es:", suma)
print("El promedio de los números es:", suma / len(numeros))
# Out:
# 1
# 2
# 3
# 4
# 5
# La suma de los números es: 15
# El promedio de los números es: 3.0

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3e1caccf-6550-41c1-86f5-78a5416e070a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
