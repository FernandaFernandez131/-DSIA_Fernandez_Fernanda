# %% [markdown]
# # TP01 \- Deepnote Fernanda Fernandez

# %% [markdown]
# Mi nombre es Fer, soy analista QA y mi expectativa es poder crecer en el mundo de los datos y la inteligencia artificial

# %%
print("Mi primer notebook en Deepnote")
# Out:
# Mi primer notebook en Deepnote

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3e1caccf-6550-41c1-86f5-78a5416e070a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
